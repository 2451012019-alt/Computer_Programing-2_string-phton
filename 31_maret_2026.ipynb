# %% [markdown]
# **memeriksa jenis tipe data**

# %% [markdown]
# kenapa data butuh dikonversi
#
# tidak semua data itu valid dan tidak semua data itu bisa

# %%
nama = "wong ganteng"
usia = 30
lajang = True

print(type(nama))
print(type(usia))
print(type(lajang))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
usia = input("Masukkan usia anda")
# Out:
# Masukkan usia anda30

# %% [markdown]
# Konversi tipe data

# %%
panjang = input("Masukkan Panjang : ")
lebar = input("Masukkan Lebar : ")
tinggi = input("Masukkan Tinggi : ")
# Out:
# Masukkan Panjang : 15
# Masukkan Lebar : 5
# Masukkan Tinggi : 10

# %% [markdown]
# konversi data secara implisit

# %%
a = 10/2
print(type(a))

b = 1/2
print(type(b))
# Out:
# <class 'float'>
# <class 'float'>

# %%
kata = "Jeruk"

print(kata)
# Out:
# Jeruk

# %% [markdown]
# tidak semua operasi dari tipe data yang berbeda bisa dikoversi

# %% [markdown]
# Konversi string ke numerik

# %%
panjang = int(input("Masukkan Panjang: "))
lebar = int(input("Masukkan Lebar: "))
tinggi = int(input("Masukkan Tinggi: "))

print("Luas =", panjang * lebar)
# Out:
# Masukkan Panjang: 15
# Masukkan Lebar: 5
# Masukkan Tinggi: 10
# Luas = 75

# %%
panjang = int(input("Masukkan Panjang: "))
lebar = int(input("Masukkan Lebar: "))

print("Luas =", panjang * lebar)
print("Keliling =", 2 * (panjang + lebar))
# Out:
# Masukkan Panjang: 15
# Masukkan Lebar: 10
# Luas = 150
# Keliling = 50

# %%
nama = 'WODIE'
tahun_lahir = 2600

print(nama + ' lahir pada tahun ' + str(tahun_lahir))

# %% [markdown]
# KESIMPULAN

# %% [markdown]
# tipe data
